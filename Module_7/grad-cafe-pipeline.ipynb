# %%
import sys
import os

# Add src to path to import our custom module
sys.path.append(os.path.abspath('src'))
from s3_fetch import download_s3_file

# Define the SHALL requirements for filenames
BUCKET = "grad-cafe" # or your specific bucket name
S3_FILE = "applicant_data.json"
LOCAL_FILE = "applicant_data_SM.json"

# Execute
download_s3_file(BUCKET, S3_FILE, LOCAL_FILE)
